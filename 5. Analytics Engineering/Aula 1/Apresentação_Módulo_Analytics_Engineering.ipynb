# %% [markdown]
# <div style="text-align: center;">
#
# ## Módulo: Analytics Engineering
# <br>
#
# <div/>
#
# <div style="text-align: left;">
#
# ### Tópicos de estudo:
#
# > ### 1. **Data Clean, Data Quality e Testes de Qualidade**;
# > ### 2. **Geração de camadas especializadas**;
# > ### 3. **Great Expectations**;
# > ### 4. **Data Build Tool - dbt**.
#
# <div/>
#
# <br>
#
# ### Metodologia:
# > ### - Aulas práticas e exercícios;
# > ### - Projeto Final:

# %% [markdown]
# ### Lucio José Suruagy Monteiro
#
# ### Email: lucio.suruagy@gmail.com
#
# ### Linkedin: https://www.linkedin.com/in/luciomonteiro/
#
# ### Telefone e Whatsapp: +55 81 99433-4793
