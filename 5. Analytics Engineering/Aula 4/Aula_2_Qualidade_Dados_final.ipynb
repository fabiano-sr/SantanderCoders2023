# %% [markdown]
# ## Módulo: Analytics Engineering
#
# ## Aula 2 - Parte 1

# %% [markdown]
# ### Programação da Aula 2:
#
# > ### 1. **Princípios de qualidade de dados e seus benefícios**:
# > ### 2. **Qualidade de dados na prática**;
# > ### 3. **Desenvolvimento de exercício**;
#
# #### Link para o formulário de Feedback da aula:
# https://forms.gle/pYhxH5MMAZYPCwvVA

# %% [markdown]
# ### **Princípios da qualidade de dados**
#
# - **Precisão:** Os dados precisos são dados que estão corretos e livres de erros. Eles são baseados em fontes confiáveis e são atualizados regularmente. A precisão dos dados pode ser afetada por erros de entrada manual, integração de dados de várias fontes, omissão de dados e duplicação de dados. Para garantir a precisão dos dados, é importante realizar verificações regulares dos dados para identificar e corrigir erros.
#
# - **Consistência:** Os dados consistentes são dados que estão no mesmo formato e mantêm as mesmas definições em todos os sistemas e processos. A consistência dos dados pode ser afetada pela falta de padronização dos dados, pela variação dos nomes de campos e pela falta de integridade referencial. Para garantir a consistência dos dados, é importante estabelecer padrões para a entrada de dados e verificar regularmente se esses padrões estão sendo seguidos.
#
# - **Confiabilidade:** Os dados confiáveis são dados que são precisos e consistentes, mas também são acessíveis e seguros. Eles são protegidos contra perda, roubo e corrupção, e podem ser acessados por usuários autorizados. A confiabilidade dos dados pode ser afetada pela falta de segurança de dados, pela falta de backups regulares e pela falta de controle de acesso aos dados. Para garantir a confiabilidade dos dados, é importante implementar práticas de segurança de dados, como backups regulares e controles de acesso.
#
# - **Relevância:** Os dados relevantes são dados que são necessários para as decisões empresariais. Eles são coletados com base nos requisitos do negócio e são relevantes para os usuários finais. A relevância dos dados pode ser afetada pela coleta de dados desnecessários ou pela falta de coleta de dados importantes. Para garantir a relevância dos dados, é importante estabelecer um processo para identificar os requisitos de dados do negócio e coletar apenas os dados necessários.
#
#
# ### **Benefícios da qualidade de dados**
#
# - **Tomada de decisão mais informada:** Dados precisos, consistentes, confiáveis e relevantes permitem que as empresas tomem decisões informadas com base em informações precisas e confiáveis.
#
# - **Redução de custos:** Dados de baixa qualidade podem levar a decisões equivocadas, o que pode levar a custos adicionais para a empresa. Ao melhorar a qualidade dos dados, as empresas podem reduzir os custos desnecessários associados à tomada de decisão equivocada.
#
# - **Melhoria da eficiência:** Dados precisos e consistentes podem ajudar a melhorar a eficiência dos processos empresariais, reduzindo o tempo gasto na correção de erros e retrabalho.
#
# - **Aumento da satisfação do cliente:** Dados precisos e relevantes permitem que as empresas entendam melhor as necessidades de seus clientes e ofereçam soluções personalizadas para atender a essas necessidades. Isso pode levar a um aumento na satisfação do cliente e na fidelidade à marca.

# %% [markdown]
# ### **Qualidade de dados na prática**

# %% [markdown]
# ### Instalação das biblioteca para verificação do perfil dos dados

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (4.6.5)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (2.0.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (3.8.3)
# Requirement already satisfied: pydantic>=2 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (2.6.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (3.1.3)
# Requirement already satisfied: visions==0.7.5 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (0.7.5)
# Requirement already satisfied: numpy<1.26,>=1.16.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (1.25.2)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (4.66.2)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (0.14.1)
# Requirement already satisfied: typeguard<5,>=4.1.2 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (4.1.5)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<0.59.0,>=0.56.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling) (0.58.1)
# Requirement already satisfied: PyWavelets in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.5.0)
# Requirement already satisfied: pillow in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata-profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (6.3.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.3.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from pydantic>=2->ydata-profiling) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from pydantic>=2->ydata-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\ljsmo\appdata\local\programs\python\python39\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from typeguard<5,>=4.1.2->ydata-profiling) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from importlib-metadata>=3.6->typeguard<5,>=4.1.2->ydata-profiling) (3.16.2)
# Requirement already satisfied: six in c:\users\ljsmo\appdata\roaming\python\python39\site-packages (from patsy>=0.5.4->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: visions 0.7.5 does not provide the extra 'type-image-path'

# %% [markdown]
# ### Chamada da bibliotecas

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# ### Dataset sobre preço de carros usados:
# https://data.world/data-society/used-cars-data

# %%
df = pd.read_csv("F:\ADA\AnalyticsEngineer\lucio\dados\\autos.csv", encoding='ISO-8859-1')
df.head(3)
# Out:
#            dateCrawled  ...             lastSeen
# 0  2016-03-24 11:52:17  ...  2016-04-07 03:16:57
# 1  2016-03-24 10:58:45  ...  2016-04-07 01:46:50
# 2  2016-03-14 12:52:21  ...  2016-04-05 12:47:46
#
# [3 rows x 20 columns]

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in f:\users\ljsmo\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython-sql) (8.20.0)
# Requirement already satisfied: sqlalchemy>=2.0 in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython-sql) (2.0.25)
# Requirement already satisfied: sqlparse in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in f:\users\ljsmo\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\users\ljsmo\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: colorama in f:\users\ljsmo\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in f:\users\ljsmo\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in f:\users\ljsmo\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in f:\users\ljsmo\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in f:\users\ljsmo\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in f:\users\ljsmo\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: sqlalchemy in f:\users\ljsmo\anaconda3\lib\site-packages (2.0.25)
# Requirement already satisfied: typing-extensions>=4.6.0 in f:\users\ljsmo\anaconda3\lib\site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\users\ljsmo\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: psycopg2 in f:\users\ljsmo\anaconda3\lib\site-packages (2.9.9)

# %%
from sqlalchemy import create_engine, text as sql_text

# %%
engine = create_engine('postgresql://postgres:ada@localhost/ada')

# %%
df.to_sql('base_autos_raw', engine, if_exists='replace', index=False)
# Out:
# 528

# %% [markdown]
# ### Comando "describe" que retorna algumas informações do DataFrame

# %%
df.describe()
# Out:
#               price  yearOfRegistration  ...  nrOfPictures    postalCode
# count  3.715280e+05       371528.000000  ...      371528.0  371528.00000
# mean   1.729514e+04         2004.577997  ...           0.0   50820.66764
# std    3.587954e+06           92.866598  ...           0.0   25799.08247
# min    0.000000e+00         1000.000000  ...           0.0    1067.00000
# 25%    1.150000e+03         1999.000000  ...           0.0   30459.00000
# 50%    2.950000e+03         2003.000000  ...           0.0   49610.00000
# 75%    7.200000e+03         2008.000000  ...           0.0   71546.00000
# max    2.147484e+09         9999.000000  ...           0.0   99998.00000
#
# [8 rows x 7 columns]

# %% [markdown]
# ### Relatório com informações do perfil dos dados a partir da biblioteca "ydata_profiling"

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("F:\ADA\AnalyticsEngineer\lucio\dados\\resultados-1.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\ljsmo\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# c:\Users\ljsmo\AppData\Local\Programs\Python\Python39\lib\site-packages\ydata_profiling\model\missing.py:78: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(missing_diagrams={"Heatmap": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: '--'')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Tipos de cada coluna no Dataframe

# %%
df.dtypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %% [markdown]
# ### Cria um dataframe copia para começar a limpeza dos dados. O primeiro passo será definir o tipo das colunas que não serão de texto.

# %%
df_cln = df.copy()

# %%
list_datetime = ['dateCrawled', 'dateCreated', 'lastSeen'] #colunas do tipo de data e hora
for column in list_datetime: 
    #transforma a coluna para o tipo "datetime" com o formato passado
    df_cln[column] = pd.to_datetime(df_cln[column], format='%Y-%m-%d %H:%M:%S')

# %%
df_cln.dtypes
# Out:
# dateCrawled            datetime64[ns]
# name                           object
# seller                         object
# offerType                      object
# price                         float64
# abtest                         object
# vehicleType                    object
# yearOfRegistration              int32
# gearbox                        object
# powerPS                       float64
# model                          object
# kilometer                     float64
# monthOfRegistration             int32
# fuelType                       object
# brand                          object
# notRepairedDamage              object
# dateCreated            datetime64[ns]
# nrOfPictures                    int32
# postalCode                      int32
# lastSeen               datetime64[ns]
# dtype: object

# %%
list_int = ['yearOfRegistration', 'monthOfRegistration', 'nrOfPictures', 'postalCode'] #colunas do tipo inteiro
for column in list_int: 
    #transforma a coluna para o tipo inteiro
    df_cln[column] = df_cln[column].astype("int")

# %%
list_float = ['price', 'powerPS', 'kilometer'] #colunas do tipo float
for column in list_float: 
    #transforma a coluna para o tipo float
    df_cln[column] = df_cln[column].astype("float")

# %% [markdown]
# ### Verifica os novos tipos de cada coluna

# %%
df_cln.dtypes
# Out:
# dateCrawled            datetime64[ns]
# name                           object
# seller                         object
# offerType                      object
# price                         float64
# abtest                         object
# vehicleType                    object
# yearOfRegistration              int32
# gearbox                        object
# powerPS                       float64
# model                          object
# kilometer                     float64
# monthOfRegistration             int32
# fuelType                       object
# brand                          object
# notRepairedDamage              object
# dateCreated            datetime64[ns]
# nrOfPictures                    int32
# postalCode                      int32
# lastSeen               datetime64[ns]
# dtype: object

# %% [markdown]
# ### Função para verificar os casos nulos

# %%
def check_missing(df_param):
    res_missing = df_param.isna().sum()
    res_missing = (res_missing/len(df_param))*100
    return res_missing

# %%
check_missing(df_cln).sort_values(ascending=False)
# Out:
# notRepairedDamage      19.395577
# vehicleType            10.192771
# fuelType                8.986133
# model                   5.513447
# gearbox                 5.439429
# kilometer               0.000000
# postalCode              0.000000
# nrOfPictures            0.000000
# dateCreated             0.000000
# brand                   0.000000
# monthOfRegistration     0.000000
# dateCrawled             0.000000
# name                    0.000000
# powerPS                 0.000000
# yearOfRegistration      0.000000
# abtest                  0.000000
# price                   0.000000
# offerType               0.000000
# seller                  0.000000
# lastSeen                0.000000
# dtype: float64

# %% [markdown]
# ### Preenchimento dos campos nulos com valores fixos

# %%
df_cln['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# nein    263182
# ja       36286
# Name: count, dtype: int64

# %%
df_cln['notRepairedDamage'] = df_cln['notRepairedDamage'].fillna("no_info")

# %%
df_cln['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# nein       263182
# no_info     72060
# ja          36286
# Name: count, dtype: int64

# %% [markdown]
# ### Preenchimento dos campos nulos com valores fixos

# %%
df_cln['vehicleType'].value_counts()
# Out:
# vehicleType
# limousine     95894
# kleinwagen    80023
# kombi         67564
# bus           30201
# cabrio        22898
# coupe         19015
# suv           14707
# andere         3357
# Name: count, dtype: int64

# %%
df_cln['vehicleType'] = df_cln['vehicleType'].fillna("no_info")

# %%
df_cln['vehicleType'].value_counts()
# Out:
# vehicleType
# limousine     95894
# kleinwagen    80023
# kombi         67564
# no_info       37869
# bus           30201
# cabrio        22898
# coupe         19015
# suv           14707
# andere         3357
# Name: count, dtype: int64

# %% [markdown]
# ### Preenchimento dos campos nulos com o campo que mais se repete

# %%
df_cln['fuelType'].value_counts()
# Out:
# fuelType
# benzin     223857
# diesel     107746
# lpg          5378
# cng           571
# hybrid        278
# andere        208
# elektro       104
# Name: count, dtype: int64

# %%
high_freq = df_cln['fuelType'].value_counts().idxmax()
df_cln['fuelType'] = df_cln['fuelType'].fillna(high_freq)

# %%
df_cln['fuelType'].value_counts()
# Out:
# fuelType
# benzin     257243
# diesel     107746
# lpg          5378
# cng           571
# hybrid        278
# andere        208
# elektro       104
# Name: count, dtype: int64

# %% [markdown]
# ### Preenchimento dos campos nulos com valores fixos

# %%
df_cln['model'].value_counts()
# Out:
# model
# golf               30070
# andere             26400
# 3er                20567
# polo               13092
# corsa              12573
#                    ...
# serie_2                8
# rangerover             6
# serie_3                4
# serie_1                2
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %%
df_cln['model'] = df_cln['model'].fillna("no_info")

# %%
df_cln['model'].value_counts()
# Out:
# model
# golf               30070
# andere             26400
# 3er                20567
# no_info            20484
# polo               13092
#                    ...
# serie_2                8
# rangerover             6
# serie_3                4
# serie_1                2
# discovery_sport        1
# Name: count, Length: 252, dtype: int64

# %% [markdown]
# ### Preenchimento dos campos nulos com valores fixos

# %%
df_cln['gearbox'].value_counts()
# Out:
# gearbox
# manuell      274214
# automatik     77105
# Name: count, dtype: int64

# %%
df_cln['gearbox'] = df_cln['gearbox'].fillna("no_info")

# %%
df_cln['gearbox'].value_counts()
# Out:
# gearbox
# manuell      274214
# automatik     77105
# no_info       20209
# Name: count, dtype: int64

# %% [markdown]
# ### Verifica os resultados nulos após o tratamento

# %%
check_missing(df_cln).sort_values(ascending=False)
# Out:
# dateCrawled            0.0
# name                   0.0
# postalCode             0.0
# nrOfPictures           0.0
# dateCreated            0.0
# notRepairedDamage      0.0
# brand                  0.0
# fuelType               0.0
# monthOfRegistration    0.0
# kilometer              0.0
# model                  0.0
# powerPS                0.0
# gearbox                0.0
# yearOfRegistration     0.0
# vehicleType            0.0
# abtest                 0.0
# price                  0.0
# offerType              0.0
# seller                 0.0
# lastSeen               0.0
# dtype: float64

# %% [markdown]
# ### Eliminando os campos duplicados

# %%
df_cln
# Out:
#                dateCrawled  ...            lastSeen
# 0      2016-03-24 11:52:17  ... 2016-04-07 03:16:57
# 1      2016-03-24 10:58:45  ... 2016-04-07 01:46:50
# 2      2016-03-14 12:52:21  ... 2016-04-05 12:47:46
# 3      2016-03-17 16:54:04  ... 2016-03-17 17:40:17
# 4      2016-03-31 17:25:20  ... 2016-04-06 10:17:21
# ...                    ...  ...                 ...
# 371523 2016-03-14 17:48:27  ... 2016-04-06 00:46:52
# 371524 2016-03-05 19:56:21  ... 2016-03-11 18:17:12
# 371525 2016-03-19 18:57:12  ... 2016-04-07 07:15:26
# 371526 2016-03-20 19:41:08  ... 2016-03-24 12:45:21
# 371527 2016-03-07 19:39:19  ... 2016-03-22 03:17:10
#
# [371528 rows x 20 columns]

# %%
print("Antes: ", len(df_cln))
df_cln = df_cln.drop_duplicates()
print("Depois: ", len(df_cln))
# Out:
# Antes:  371528
# Depois:  371524

# %% [markdown]
# ### Eliminando as colunas constantes

# %%
list_constant = [col for col in df_cln.columns if df_cln[col].nunique() ==1]
list_constant
# Out:
# ['nrOfPictures']

# %%
print("Antes: ", len(df_cln.columns))
df_cln = df_cln.drop(list_constant, axis=1)
print("Depois: ", len(df_cln.columns))
# Out:
# Antes:  20
# Depois:  19

# %% [markdown]
# ### Eliminando as colunas extremamente desbalanceadas

# %%
df_cln['offerType'].value_counts(normalize=True)
# Out:
# offerType
# Angebot    0.999968
# Gesuch     0.000032
# Name: proportion, dtype: float64

# %%
df_cln['seller'].value_counts(normalize=True)
# Out:
# seller
# privat        0.999992
# gewerblich    0.000008
# Name: proportion, dtype: float64

# %%
df_cln['offerType'].value_counts(normalize=True).values[0]
# Out:
# 0.999991925151538

# %%
list_1 = []
limit = 0.98
for col in df_cln.columns:
    perc = df_cln[col].value_counts(normalize=True).values[0]
    if perc > limit:
        list_1.append(col)
        print(col, perc)
# Out:
# seller 0.999991925151538
# offerType 0.9999677006061519

# %%
df_cln = df_cln.drop(list_1, axis=1)

# %%
df_cln
# Out:
#                dateCrawled  ...            lastSeen
# 0      2016-03-24 11:52:17  ... 2016-04-07 03:16:57
# 1      2016-03-24 10:58:45  ... 2016-04-07 01:46:50
# 2      2016-03-14 12:52:21  ... 2016-04-05 12:47:46
# 3      2016-03-17 16:54:04  ... 2016-03-17 17:40:17
# 4      2016-03-31 17:25:20  ... 2016-04-06 10:17:21
# ...                    ...  ...                 ...
# 371523 2016-03-14 17:48:27  ... 2016-04-06 00:46:52
# 371524 2016-03-05 19:56:21  ... 2016-03-11 18:17:12
# 371525 2016-03-19 18:57:12  ... 2016-04-07 07:15:26
# 371526 2016-03-20 19:41:08  ... 2016-03-24 12:45:21
# 371527 2016-03-07 19:39:19  ... 2016-03-22 03:17:10
#
# [371524 rows x 17 columns]

# %% [markdown]
# ### Verificação dos resultados depois de eliminar as colunas extremamente desbalanceadas

# %%
list_1 = []
limit = 0.98
for col in df_cln.columns:
    perc = df_cln[col].value_counts(normalize=True).values[0]
    if perc > limit:
        list_1.append(col)
        print(col, perc)

# %% [markdown]
# ### Verificação da precisão dos dados

# %% [markdown]
# ### Os meses precisam estar no intervalo: 1 <= meses <= 12

# %%
df_cln[(df_cln['monthOfRegistration']<1) | (df_cln['monthOfRegistration']>12)]
# Out:
#                dateCrawled  ...            lastSeen
# 0      2016-03-24 11:52:17  ... 2016-04-07 03:16:57
# 9      2016-03-17 10:53:50  ... 2016-03-31 17:17:06
# 15     2016-03-11 21:39:15  ... 2016-03-19 08:46:47
# 16     2016-04-01 12:46:46  ... 2016-04-01 12:46:46
# 36     2016-03-11 11:50:37  ... 2016-04-07 03:46:09
# ...                    ...  ...                 ...
# 371460 2016-04-03 13:46:24  ... 2016-04-05 12:44:38
# 371473 2016-03-15 19:57:11  ... 2016-03-19 15:49:00
# 371482 2016-03-31 19:36:18  ... 2016-04-06 13:44:44
# 371486 2016-03-30 20:55:30  ... 2016-04-07 13:50:41
# 371494 2016-03-26 14:38:18  ... 2016-04-06 20:45:16
#
# [37675 rows x 17 columns]

# %%
df_cln.loc[(df_cln['monthOfRegistration']<1) | (df_cln['monthOfRegistration']>12), 'monthOfRegistration'] = -1

# %%
df_cln[(df_cln['monthOfRegistration']<1) | (df_cln['monthOfRegistration']>12)]
# Out:
#                dateCrawled  ...            lastSeen
# 0      2016-03-24 11:52:17  ... 2016-04-07 03:16:57
# 9      2016-03-17 10:53:50  ... 2016-03-31 17:17:06
# 15     2016-03-11 21:39:15  ... 2016-03-19 08:46:47
# 16     2016-04-01 12:46:46  ... 2016-04-01 12:46:46
# 36     2016-03-11 11:50:37  ... 2016-04-07 03:46:09
# ...                    ...  ...                 ...
# 371460 2016-04-03 13:46:24  ... 2016-04-05 12:44:38
# 371473 2016-03-15 19:57:11  ... 2016-03-19 15:49:00
# 371482 2016-03-31 19:36:18  ... 2016-04-06 13:44:44
# 371486 2016-03-30 20:55:30  ... 2016-04-07 13:50:41
# 371494 2016-03-26 14:38:18  ... 2016-04-06 20:45:16
#
# [37675 rows x 17 columns]

# %% [markdown]
# ### Verificação do resultado

# %%
df_cln[((df_cln['monthOfRegistration']<1) | (df_cln['monthOfRegistration']>12)) & (df_cln['monthOfRegistration']!=-1)]
# Out:
# Empty DataFrame
# Columns: [dateCrawled, name, price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage, dateCreated, postalCode, lastSeen]
# Index: []

# %% [markdown]
# ### O Ano precisam estar no intervalo: 1900 <= ano <= 2016

# %%
df_cln.loc[(df_cln['yearOfRegistration']<1900) | (df_cln['yearOfRegistration']>2016), 'yearOfRegistration'] = 1900

# %% [markdown]
# ### Verificação do resultado

# %%
df_cln[(df_cln['yearOfRegistration']<1900) | (df_cln['yearOfRegistration']>2016)]
# Out:
# Empty DataFrame
# Columns: [dateCrawled, name, price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage, dateCreated, postalCode, lastSeen]
# Index: []

# %% [markdown]
# ### Os preços precisam ser maiores que 0

# %%
df_cln[(df_cln['price']<=0) ]
# Out:
#                dateCrawled  ...            lastSeen
# 7      2016-03-21 18:54:38  ... 2016-03-25 16:47:58
# 40     2016-03-26 22:06:17  ... 2016-03-27 17:43:34
# 115    2016-03-19 18:40:12  ... 2016-04-01 08:47:05
# 119    2016-03-20 18:53:27  ... 2016-04-07 02:45:22
# 157    2016-03-11 18:55:53  ... 2016-03-12 23:47:10
# ...                    ...  ...                 ...
# 371356 2016-03-09 15:56:30  ... 2016-03-30 11:16:08
# 371392 2016-03-20 14:55:07  ... 2016-04-06 18:45:23
# 371402 2016-03-24 13:48:05  ... 2016-04-07 05:17:24
# 371431 2016-03-10 22:55:50  ... 2016-03-12 23:46:32
# 371522 2016-03-21 09:50:58  ... 2016-03-21 10:42:49
#
# [10778 rows x 17 columns]

# %%
df_cln = df_cln[df_cln['price']>0]

# %%
df_cln[(df_cln['price']<=0) ]
# Out:
# Empty DataFrame
# Columns: [dateCrawled, name, price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage, dateCreated, postalCode, lastSeen]
# Index: []

# %%
df_cln.to_sql('base_autos_raw_2', engine, if_exists='replace', index=False)
# Out:
# 746

# %%
query = """
SELECT *
FROM base_autos_raw_2
"""
df_cln = pd.read_sql(sql=sql_text(query), con=engine.connect())
df_cln
# Out:
#                dateCrawled                                          name  \
# 0      2016-03-24 11:52:17                                    Golf_3_1.6
# 1      2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2      2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3      2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4      2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                    ...                                           ...
# 360741 2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 360742 2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 360743 2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 360744 2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 360745 2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480.0     test     no_info                1993    manuell      0.0
# 1       18300.0     test       coupe                2011    manuell    190.0
# 2        9800.0     test         suv                2004  automatik    163.0
# 3        1500.0     test  kleinwagen                2001    manuell     75.0
# 4        3600.0     test  kleinwagen                2008    manuell     69.0
# ...         ...      ...         ...                 ...        ...      ...
# 360741   2200.0     test     no_info                2005    no_info      0.0
# 360742   1199.0     test      cabrio                2000  automatik    101.0
# 360743   9200.0     test         bus                1996    manuell    102.0
# 360744   3400.0     test       kombi                2002    manuell    100.0
# 360745  28990.0  control   limousine                2013    manuell    320.0
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf   150000.0                   -1   benzin      volkswagen
# 1           no_info   125000.0                    5   diesel            audi
# 2             grand   125000.0                    8   diesel            jeep
# 3              golf   150000.0                    6   benzin      volkswagen
# 4             fabia    90000.0                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 360741      no_info    20000.0                    1   benzin  sonstige_autos
# 360742       fortwo   125000.0                    3   benzin           smart
# 360743  transporter   150000.0                    3   diesel      volkswagen
# 360744         golf   150000.0                    6   diesel      volkswagen
# 360745      m_reihe    50000.0                    8   benzin             bmw
#
#        notRepairedDamage dateCreated  postalCode            lastSeen
# 0                no_info  2016-03-24       70435 2016-04-07 03:16:57
# 1                     ja  2016-03-24       66954 2016-04-07 01:46:50
# 2                no_info  2016-03-14       90480 2016-04-05 12:47:46
# 3                   nein  2016-03-17       91074 2016-03-17 17:40:17
# 4                   nein  2016-03-31       60437 2016-04-06 10:17:21
# ...                  ...         ...         ...                 ...
# 360741           no_info  2016-03-14       39576 2016-04-06 00:46:52
# 360742              nein  2016-03-05       26135 2016-03-11 18:17:12
# 360743              nein  2016-03-19       87439 2016-04-07 07:15:26
# 360744           no_info  2016-03-20       40764 2016-03-24 12:45:21
# 360745              nein  2016-03-07       73326 2016-03-22 03:17:10
#
# [360746 rows x 17 columns]

# %%
df_cln.describe()
# Out:
#                          dateCrawled         price  yearOfRegistration  \
# count                         360746  3.607460e+05       360746.000000
# mean   2016-03-21 13:28:33.416300544  1.781203e+04         1998.905718
# min              2016-03-05 14:06:22  1.000000e+00         1900.000000
# 25%    2016-03-13 12:50:46.249999872  1.250000e+03         1998.000000
# 50%              2016-03-21 18:06:19  3.000000e+03         2003.000000
# 75%              2016-03-29 14:50:34  7.490000e+03         2007.000000
# max              2016-04-07 14:36:58  2.147484e+09         2016.000000
# std                              NaN  3.641176e+06           21.095961
#
#              powerPS      kilometer  monthOfRegistration  \
# count  360746.000000  360746.000000        360746.000000
# mean      116.575923  125661.823000             5.703282
# min         0.000000    5000.000000            -1.000000
# 25%        72.000000  100000.000000             3.000000
# 50%       105.000000  150000.000000             6.000000
# 75%       150.000000  150000.000000             9.000000
# max     20000.000000  150000.000000            12.000000
# std       190.609039   39836.433575             3.837602
#
#                          dateCreated     postalCode  \
# count                         360746  360746.000000
# mean   2016-03-20 19:38:18.377251584   50996.062246
# min              2014-03-10 00:00:00    1067.000000
# 25%              2016-03-13 00:00:00   30823.000000
# 50%              2016-03-21 00:00:00   49751.000000
# 75%              2016-03-29 00:00:00   71672.000000
# max              2016-04-07 00:00:00   99998.000000
# std                              NaN   25760.472206
#
#                             lastSeen
# count                         360746
# mean   2016-03-30 04:41:29.232967168
# min              2016-03-05 14:15:08
# 25%    2016-03-23 12:48:59.249999872
# 50%              2016-04-04 02:44:25
# 75%              2016-04-06 10:45:56
# max              2016-04-07 14:58:51
# std                              NaN

# %% [markdown]
# ### Eliminação de Outliers

# %% [markdown]
# #### Exemplo de distribuição e quantil
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20201127112813/NORMALDISTRIBUTION-660x362.png"  width="80%" height="60%">

# %%
df_cln[['price', 'powerPS']].quantile(.02)
# Out:
# price      200.0
# powerPS      0.0
# Name: 0.02, dtype: float64

# %%
df_cln[['price', 'powerPS']].quantile(.98)
# Out:
# price      28500.0
# powerPS      300.0
# Name: 0.98, dtype: float64

# %%
print("Quantidade de linhas antes de eliminar os outliers:", len(df_cln))
list_quantile = ['price','powerPS']
df_aux = df_cln.copy()
for col in list_quantile:
    low_limit = df_aux[col].quantile(.02)
    high_limit = df_aux[col].quantile(.98)
    df_cln = df_cln[(df_cln[col]>low_limit) & (df_cln[col]<high_limit)]
print("Quantidade de linhas antes de eliminar os outliers:", len(df_cln))
# Out:
# Quantidade de linhas antes de eliminar os outliers: 360746
# Quantidade de linhas antes de eliminar os outliers: 306747

# %%
df_cln.describe()
# Out:
#                          dateCrawled          price  yearOfRegistration  \
# count                         306747  306747.000000       306747.000000
# mean   2016-03-21 13:48:27.800284928    5340.119343         1999.688421
# min              2016-03-05 14:06:23     202.000000         1900.000000
# 25%              2016-03-13 12:43:02    1440.000000         1999.000000
# 50%              2016-03-21 18:43:48    3300.000000         2003.000000
# 75%              2016-03-29 15:06:20    7450.000000         2007.000000
# max              2016-04-07 14:36:58   28499.000000         2016.000000
# std                              NaN    5444.798096           19.581832
#
#              powerPS      kilometer  monthOfRegistration  \
# count  306747.000000  306747.000000        306747.000000
# mean      120.376809  126738.224009             5.936378
# min         1.000000    5000.000000            -1.000000
# 25%        80.000000  125000.000000             3.000000
# 50%       115.000000  150000.000000             6.000000
# 75%       150.000000  150000.000000             9.000000
# max       299.000000  150000.000000            12.000000
# std        49.774169   38105.625551             3.691866
#
#                          dateCreated     postalCode  \
# count                         306747  306747.000000
# mean   2016-03-20 19:53:57.919197440   51358.191099
# min              2015-03-20 00:00:00    1067.000000
# 25%              2016-03-13 00:00:00   31084.000000
# 50%              2016-03-21 00:00:00   50354.000000
# 75%              2016-03-29 00:00:00   72160.000000
# max              2016-04-07 00:00:00   99998.000000
# std                              NaN   25740.200570
#
#                             lastSeen
# count                         306747
# mean   2016-03-30 07:08:33.236644352
# min              2016-03-05 14:15:08
# 25%       2016-03-23 16:49:53.500000
# 50%              2016-04-04 08:44:28
# 75%              2016-04-06 11:16:01
# max              2016-04-07 14:58:51
# std                              NaN

# %% [markdown]
# ### Gera os novos resultados

# %%
profile = ProfileReport(df_cln, title="Pandas Profiling Report - Versão Final")
profile.to_file("F:\ADA\AnalyticsEngineer\lucio\dados\\resultados-2.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_cln.to_sql('base_autos_silver', engine, if_exists='replace', index=False)
# Out:
# 747

# %%
df_cln.to_sql('base_autos_gold', engine, if_exists='replace', index=False)
# Out:
# 747
